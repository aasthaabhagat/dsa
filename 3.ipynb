# %%
#print nos without using loop
def printnos(n):
    if n < 1:
        return
    printnos(n - 1)
    print(n, end=" ")

if __name__ == "__main__":
    n = 5
    printnos(n)
# Out:
# 1 2 3 4 5

# %%
def printnos(n):
    if n < 1:
        return
    printnos(n - 1)
    print(n, end=" ")

# Direct execution
n = 5
printnos(n)
# Out:
# 1 2 3 4 5
